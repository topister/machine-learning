# %% [markdown]
# ## [Problem 1] Looking back on scratch

# %% [markdown]
# ### When implementing deep learning from scratch:
#
# I had to initialize weights randomly.
#
# I had to iterate through epochs to train the model.
#
# I had to Create mini-batches for efficient training.
#
# I had to Compute predictions through layers of neurons.
#
# I had to compute gradients and update weights using optimization algorithms.

# %% [markdown]
# ## [Problem 2] Consider the correspondence between scratch and TensorFlow

# %% [markdown]
# TensorFlow uses tf.Variable to declare weights and biases, initialized with tf.random_normal.
#
# Epoch loop implemented using a Python loop over num_epochs.
#
# Mini-batch iteration was achieved through a custom iterator GetMiniBatch, iterating through the dataset in batches.
#
# Forward propagation. Defined in example_net() function, applying activation functions like tf.nn.relu.
#
# Backward propagation and Optimization. Handled by optimizer.minimize(loss_op) where loss_op is the defined loss function.

# %% [markdown]
# ## [Problem 3] Create a model of Iris using all three types of objective variables

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf

# Load dataset
df = pd.read_csv("Iris.csv")

# Extract all three types of Iris species
X = df.loc[:, ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]
y = df["Species"]

# Convert species to numerical labels
label_map = {
    "Iris-setosa": 0,
    "Iris-versicolor": 1,
    "Iris-virginica": 2
}
y = y.map(label_map)
y = np.array(y)

# Convert features to NumPy array
X = np.array(X)

# Split dataset into train, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# Hyperparameters
learning_rate = 0.001
batch_size = 10
num_epochs = 100

n_input = X_train.shape[1]
n_samples = X_train.shape[0]
n_classes = 3  # Three classes: Iris-setosa, Iris-versicolor, Iris-virginica

# Convert labels to one-hot encoding
y_train_onehot = tf.keras.utils.to_categorical(y_train, num_classes=n_classes)
y_val_onehot = tf.keras.utils.to_categorical(y_val, num_classes=n_classes)
y_test_onehot = tf.keras.utils.to_categorical(y_test, num_classes=n_classes)

# Define the model using Keras Sequential API
model = tf.keras.Sequential([
    tf.keras.layers.Dense(50, activation='relu', input_shape=(n_input,)),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train_onehot,
                    batch_size=batch_size,
                    epochs=num_epochs,
                    validation_data=(X_val, y_val_onehot))

# Evaluate the model on test set
test_loss, test_acc = model.evaluate(X_test, y_test_onehot, verbose=2)
print("\nTest Accuracy:", test_acc)
# Out:
# Epoch 1/100
# /home/topister/Desktop/dpro/machine-learning/dpro/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4259 - loss: 1.0632 - val_accuracy: 0.7083 - val_loss: 0.9398
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5906 - loss: 0.9287 - val_accuracy: 0.9167 - val_loss: 0.8500
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8418 - loss: 0.8123 - val_accuracy: 0.7083 - val_loss: 0.7285
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6526 - loss: 0.7126 - val_accuracy: 0.7083 - val_loss: 0.6370
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7529 - loss: 0.6067 - val_accuracy: 0.7083 - val_loss: 0.5545
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8667 - loss: 0.5505 - val_accuracy: 0.8750 - val_loss: 0.4917
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8255 - loss: 0.4449 - val_accuracy: 0.7083 - val_loss: 0.4494
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9233 - loss: 0.3818 - val_accuracy: 0.9167 - val_loss: 0.4114
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9766 - loss: 0.3473 - val_accuracy: 0.9167 - val_loss: 0.3847
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9641 - loss: 0.2973 - val_accuracy: 0.9167 - val_loss: 0.3612
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0345 - val_accuracy: 0.9167 - val_loss: 0.2132
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9854 - loss: 0.0453 - val_accuracy: 0.9167 - val_loss: 0.2071
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9721 - loss: 0.0643 - val_accuracy: 0.9167 - val_loss: 0.2512
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9608 - loss: 0.0584 - val_accuracy: 0.9167 - val_loss: 0.2074
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9906 - loss: 0.0288 - val_accuracy: 0.9167 - val_loss: 0.2410
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9659 - loss: 0.0540 - val_accuracy: 0.9167 - val_loss: 0.2043
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0681 - val_accuracy: 0.9167 - val_loss: 0.3037
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9652 - loss: 0.0527 - val_accuracy: 0.9167 - val_loss: 0.1910
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9796 - loss: 0.0480 - val_accuracy: 0.9167 - val_loss: 0.2534
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9724 - loss: 0.0435 - val_accuracy: 0.9167 - val_loss: 0.2041
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9931 - loss: 0.0292 - val_accuracy: 0.9167 - val_loss: 0.2377
# 1/1 - 0s - 19ms/step - accuracy: 1.0000 - loss: 0.0271
#
# Test Accuracy: 1.0

# %% [markdown]
# ## [Problem 4] Create a model of House Prices

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np

# Load dataset
df_house = pd.read_csv("../train.csv")

# Select features and target variable
X_house = df_house.loc[:, ["GrLivArea", "YearBuilt"]]
y_house = df_house["SalePrice"]

# Convert to NumPy arrays
X_house = np.array(X_house)
y_house = np.array(y_house)[:, np.newaxis]  # Ensure y has shape (n_samples, 1)

# Split dataset into train, validation, and test sets
X_train_house, X_test_house, y_train_house, y_test_house = train_test_split(X_house, y_house, test_size=0.2, random_state=0)
X_train_house, X_val_house, y_train_house, y_val_house = train_test_split(X_train_house, y_train_house, test_size=0.2, random_state=0)

# Hyperparameters
learning_rate_house = 0.001
batch_size_house = 10
num_epochs_house = 100

n_input_house = X_train_house.shape[1]
n_samples_house = X_train_house.shape[0]

# Define the model using Keras Sequential API
model_house = tf.keras.Sequential([
    tf.keras.layers.Dense(50, activation='relu', input_shape=(n_input_house,)),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(1)  # No activation function for regression
])

# Compile the model
model_house.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_house),
                    loss='mean_squared_error')

# Train the model
history_house = model_house.fit(X_train_house, y_train_house,
                                batch_size=batch_size_house,
                                epochs=num_epochs_house,
                                validation_data=(X_val_house, y_val_house))

# Evaluate the model on test set
test_loss_house = model_house.evaluate(X_test_house, y_test_house, verbose=2)
print("\nTest Loss:", test_loss_house)
# Out:
# Epoch 1/100
# /home/topister/Desktop/dpro/machine-learning/dpro/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37643063296.0000 - val_loss: 29426548736.0000
# Epoch 2/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24882538496.0000 - val_loss: 5872673280.0000
# Epoch 3/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4766485504.0000 - val_loss: 3023371776.0000
# Epoch 4/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3000774656.0000 - val_loss: 3070917632.0000
# Epoch 5/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3252205824.0000 - val_loss: 2903746560.0000
# Epoch 6/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3881720832.0000 - val_loss: 2780298496.0000
# Epoch 7/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3701769472.0000 - val_loss: 2759139072.0000
# Epoch 8/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3212456192.0000 - val_loss: 2687715328.0000
# Epoch 9/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3026806272.0000 - val_loss: 2702244608.0000
# Epoch 10/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3269354240.0000 - val_loss: 2612827904.0000
# Epoch 11/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3542528768.0000 - val_loss: 2545669120.0000
# Epoch 12/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3904410112.0000 - val_loss: 2505731072.0000
# Epoch 13/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3575046656.0000 - val_loss: 2556696576.0000
# Epoch 14/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3259828736.0000 - val_loss: 2478780928.0000
# Epoch 15/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3678236928.0000 - val_loss: 2451303680.0000
# Epoch 16/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2875912960.0000 - val_loss: 2518966272.0000
# Epoch 17/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3229739520.0000 - val_loss: 2483798528.0000
# Epoch 18/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3126452992.0000 - val_loss: 2490130432.0000
# Epoch 19/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3558151680.0000 - val_loss: 2502357760.0000
# Epoch 20/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3361560832.0000 - val_loss: 2429925120.0000
# Epoch 21/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3082680832.0000 - val_loss: 2427784960.0000
# Epoch 22/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2899590912.0000 - val_loss: 2435922688.0000
# Epoch 23/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3018046464.0000 - val_loss: 2430102016.0000
# Epoch 24/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3101421312.0000 - val_loss: 2456500480.0000
# Epoch 25/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2900444672.0000 - val_loss: 2561378304.0000
# Epoch 26/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3297095680.0000 - val_loss: 2492340736.0000
# Epoch 27/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3087227136.0000 - val_loss: 2446631680.0000
# Epoch 28/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3401639936.0000 - val_loss: 2435427840.0000
# Epoch 29/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3011935488.0000 - val_loss: 2484339200.0000
# Epoch 30/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3296936704.0000 - val_loss: 2484902144.0000
# Epoch 31/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2708015104.0000 - val_loss: 2447178752.0000
# Epoch 32/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3023051008.0000 - val_loss: 2491756288.0000
# Epoch 33/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3094464000.0000 - val_loss: 2573943552.0000
# Epoch 34/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3026359552.0000 - val_loss: 2473947648.0000
# Epoch 35/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2747334400.0000 - val_loss: 2543545600.0000
# Epoch 36/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2992761344.0000 - val_loss: 2543813888.0000
# Epoch 37/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3046722560.0000 - val_loss: 2479756544.0000
# Epoch 38/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2881751808.0000 - val_loss: 2449228800.0000
# Epoch 39/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3216202752.0000 - val_loss: 2667478784.0000
# Epoch 40/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2647021056.0000 - val_loss: 2521155840.0000
# Epoch 41/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2920432384.0000 - val_loss: 2532645888.0000
# Epoch 42/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3191742464.0000 - val_loss: 2521713152.0000
# Epoch 43/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2919790592.0000 - val_loss: 2436590336.0000
# Epoch 44/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2746370560.0000 - val_loss: 2444773632.0000
# Epoch 45/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3080914176.0000 - val_loss: 2541459200.0000
# Epoch 46/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2747607296.0000 - val_loss: 2443615232.0000
# Epoch 47/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3524514816.0000 - val_loss: 2436321792.0000
# Epoch 48/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3139787264.0000 - val_loss: 2436991232.0000
# Epoch 49/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3325987584.0000 - val_loss: 2470456576.0000
# Epoch 50/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2954664192.0000 - val_loss: 2443949824.0000
# Epoch 51/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3033975808.0000 - val_loss: 2442373632.0000
# Epoch 52/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2929433600.0000 - val_loss: 2496391680.0000
# Epoch 53/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3108065536.0000 - val_loss: 2492719616.0000
# Epoch 54/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3579147008.0000 - val_loss: 2470909440.0000
# Epoch 55/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2829529600.0000 - val_loss: 2664607744.0000
# Epoch 56/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2895438848.0000 - val_loss: 2458526464.0000
# Epoch 57/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3281899520.0000 - val_loss: 2441523200.0000
# Epoch 58/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3214755328.0000 - val_loss: 2456133376.0000
# Epoch 59/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3387862784.0000 - val_loss: 2453731584.0000
# Epoch 60/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3232422144.0000 - val_loss: 2441790208.0000
# Epoch 61/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3011081728.0000 - val_loss: 2462351104.0000
# Epoch 62/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2899659264.0000 - val_loss: 2700353024.0000
# Epoch 63/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3300111360.0000 - val_loss: 2523817472.0000
# Epoch 64/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2802658816.0000 - val_loss: 2438940416.0000
# Epoch 65/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3289464576.0000 - val_loss: 2470761472.0000
# Epoch 66/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2931598848.0000 - val_loss: 2440513280.0000
# Epoch 67/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2988719872.0000 - val_loss: 2460025088.0000
# Epoch 68/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2903869696.0000 - val_loss: 2489093376.0000
# Epoch 69/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2737931520.0000 - val_loss: 2449517568.0000
# Epoch 70/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2896637952.0000 - val_loss: 2463376384.0000
# Epoch 71/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3394217216.0000 - val_loss: 2444564480.0000
# Epoch 72/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3182451456.0000 - val_loss: 2563074816.0000
# Epoch 73/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3220470528.0000 - val_loss: 2453709056.0000
# Epoch 74/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3017891840.0000 - val_loss: 2457571072.0000
# Epoch 75/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3279753216.0000 - val_loss: 2454546432.0000
# Epoch 76/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3279504640.0000 - val_loss: 2443790336.0000
# Epoch 77/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3239312384.0000 - val_loss: 2472307712.0000
# Epoch 78/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3239838976.0000 - val_loss: 2463266048.0000
# Epoch 79/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2956954368.0000 - val_loss: 2537772544.0000
# Epoch 80/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2732271616.0000 - val_loss: 2441829632.0000
# Epoch 81/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2901762560.0000 - val_loss: 2437798656.0000
# Epoch 82/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3221052928.0000 - val_loss: 2467970048.0000
# Epoch 83/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2901582336.0000 - val_loss: 2602579200.0000
# Epoch 84/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2882277888.0000 - val_loss: 2633123072.0000
# Epoch 85/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2775223808.0000 - val_loss: 2508663808.0000
# Epoch 86/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3111961600.0000 - val_loss: 2461431040.0000
# Epoch 87/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3144257792.0000 - val_loss: 2467896064.0000
# Epoch 88/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3227602944.0000 - val_loss: 2471207424.0000
# Epoch 89/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3066821888.0000 - val_loss: 2469955328.0000
# Epoch 90/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3083596800.0000 - val_loss: 2514970112.0000
# Epoch 91/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2902667776.0000 - val_loss: 2477662208.0000
# Epoch 92/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3225860352.0000 - val_loss: 2511294720.0000
# Epoch 93/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2877783040.0000 - val_loss: 2440609024.0000
# Epoch 94/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2698128384.0000 - val_loss: 2509209600.0000
# Epoch 95/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2988092672.0000 - val_loss: 2462173184.0000
# Epoch 96/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3245867776.0000 - val_loss: 2479379968.0000
# Epoch 97/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2890400512.0000 - val_loss: 2480047104.0000
# Epoch 98/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3299688704.0000 - val_loss: 2440094720.0000
# Epoch 99/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2919933952.0000 - val_loss: 2461178368.0000
# Epoch 100/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2840927744.0000 - val_loss: 2474624256.0000
# 10/10 - 0s - 9ms/step - loss: 3821440512.0000
#
# Test Loss: 3821440512.0

# %% [markdown]
# ## [Problem 5] Create a model of MNIST

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(X_train_mnist, y_train_mnist), (X_test_mnist, y_test_mnist) = mnist.load_data()

# Flatten images and normalize
X_train_mnist = X_train_mnist.reshape(-1, 28*28) / 255.0
X_test_mnist = X_test_mnist.reshape(-1, 28*28) / 255.0

# Convert labels to categorical one-hot encoded
y_train_mnist = to_categorical(y_train_mnist, num_classes=10)
y_test_mnist = to_categorical(y_test_mnist, num_classes=10)

# Hyperparameters
learning_rate_mnist = 0.001
batch_size_mnist = 100
num_epochs_mnist = 20

n_input_mnist = X_train_mnist.shape[1]
n_samples_mnist = X_train_mnist.shape[0]
n_classes_mnist = 10  # 10 classes (0-9 digits)

# Define the model using Keras Sequential API
model_mnist = tf.keras.Sequential([
    tf.keras.layers.Dense(50, activation='relu', input_shape=(n_input_mnist,)),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(n_classes_mnist, activation='softmax')
])

# Compile the model
model_mnist.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_mnist),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# Train the model
history_mnist = model_mnist.fit(X_train_mnist, y_train_mnist,
                                batch_size=batch_size_mnist,
                                epochs=num_epochs_mnist,
                                validation_data=(X_test_mnist, y_test_mnist))

# Evaluate the model on test set
test_loss_mnist, test_acc_mnist = model_mnist.evaluate(X_test_mnist, y_test_mnist, verbose=2)
print("\nTest Accuracy:", test_acc_mnist)
# Out:
# Epoch 1/20
# 2024-07-02 13:41:37.163812: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8098 - loss: 0.6728 - val_accuracy: 0.9386 - val_loss: 0.2062
# Epoch 2/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9502 - loss: 0.1746 - val_accuracy: 0.9538 - val_loss: 0.1538
# Epoch 3/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9619 - loss: 0.1298 - val_accuracy: 0.9609 - val_loss: 0.1229
# Epoch 4/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9704 - loss: 0.0992 - val_accuracy: 0.9665 - val_loss: 0.1083
# Epoch 5/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9748 - loss: 0.0830 - val_accuracy: 0.9688 - val_loss: 0.1047
# Epoch 6/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9775 - loss: 0.0720 - val_accuracy: 0.9691 - val_loss: 0.1007
# Epoch 7/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9820 - loss: 0.0585 - val_accuracy: 0.9691 - val_loss: 0.1007
# Epoch 8/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9852 - loss: 0.0504 - val_accuracy: 0.9728 - val_loss: 0.0966
# Epoch 9/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9857 - loss: 0.0456 - val_accuracy: 0.9730 - val_loss: 0.0981
# Epoch 10/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9872 - loss: 0.0398 - val_accuracy: 0.9738 - val_loss: 0.0952
# Epoch 11/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9900 - loss: 0.0333 - val_accuracy: 0.9723 - val_loss: 0.0996
# Epoch 12/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9909 - loss: 0.0322 - val_accuracy: 0.9695 - val_loss: 0.1062
# Epoch 13/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9911 - loss: 0.0286 - val_accuracy: 0.9737 - val_loss: 0.1004
# Epoch 14/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9914 - loss: 0.0260 - val_accuracy: 0.9742 - val_loss: 0.0980
# Epoch 15/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9944 - loss: 0.0199 - val_accuracy: 0.9703 - val_loss: 0.1063
# Epoch 16/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0185 - val_accuracy: 0.9723 - val_loss: 0.1124
# Epoch 17/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9947 - loss: 0.0168 - val_accuracy: 0.9732 - val_loss: 0.1105
# Epoch 18/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9960 - loss: 0.0143 - val_accuracy: 0.9717 - val_loss: 0.1169
# Epoch 19/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9950 - loss: 0.0149 - val_accuracy: 0.9715 - val_loss: 0.1177
# Epoch 20/20
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0127 - val_accuracy: 0.9727 - val_loss: 0.1277
# 313/313 - 0s - 1ms/step - accuracy: 0.9727 - loss: 0.1277
#
# Test Accuracy: 0.9726999998092651
